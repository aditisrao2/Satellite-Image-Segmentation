# %% [markdown]
# # Multiclass Semantic Segmentation using U-Net with ResNet as the Backbone

# %%
import os
import cv2
import numpy as np
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

from tensorflow import keras
from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
import segmentation_models as sm
from tensorflow.keras.metrics import MeanIoU

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
scaler = MinMaxScaler()
root_directory = './Semantic segmentation dataset'

patch_size = 256

# %%
# Read images from the 'images' subdirectory under each Tile (1-8)
# All the images are of different sizes.
# Option 1: RESIZE, Some images are too large and some small. Resizing will change the size of real objects.
# Option 2: CROP, cropping them to the nearest size divisible by 256 and then dividing all the images into patches of 256x256x3. 
image_dataset = []  
for path, subdirs, files in os.walk(root_directory):
    # print(path)  
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'images':   # Find all 'images' directories
        images = sorted(os.listdir(path))  # List of all image names in this subdirectory
        for i, image_name in enumerate(images):  
            if image_name.endswith(".jpg"):   # Only read jpg images...
               
                image = cv2.imread(path+"/"+image_name, 1)  # Read each image as BGR
                SIZE_X = (image.shape[1]//patch_size)*patch_size # Nearest size divisible by our patch size
                SIZE_Y = (image.shape[0]//patch_size)*patch_size # Nearest size divisible by our patch size
                image = Image.fromarray(image)
                image = image.crop((0 ,0, SIZE_X, SIZE_Y))  # Crop from top left corner
                # image = image.resize((SIZE_X, SIZE_Y))  # Try not to resize for semantic segmentation
                image = np.array(image)             
       
                # Extract patches from each image
                print("Now patchifying image:", path+"/"+image_name)
                patches_img = patchify(image, (patch_size, patch_size, 3), step=patch_size)  # Step=256 for 256 patches means no overlap
        
                for i in range(patches_img.shape[0]):
                    for j in range(patches_img.shape[1]):
                        
                        single_patch_img = patches_img[i,j,:,:]
                        
                        # Use minmaxscaler instead of just dividing by 255. 
                        single_patch_img = scaler.fit_transform(single_patch_img.reshape(-1, single_patch_img.shape[-1])).reshape(single_patch_img.shape)
                        
                        # single_patch_img = (single_patch_img.astype('float32')) / 255. 
                        single_patch_img = single_patch_img[0] # Drop the extra unecessary dimension that patchify adds.                               
                        image_dataset.append(single_patch_img)
# Out:
# Now patchifying image: ./Semantic segmentation dataset\Tile 1\images/image_part_001.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 1\images/image_part_002.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 1\images/image_part_003.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 1\images/image_part_004.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 1\images/image_part_005.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 1\images/image_part_006.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 1\images/image_part_007.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 1\images/image_part_008.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 1\images/image_part_009.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 2\images/image_part_001.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 2\images/image_part_002.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 2\images/image_part_003.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 2\images/image_part_004.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 2\images/image_part_005.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 2\images/image_part_006.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 2\images/image_part_007.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 2\images/image_part_008.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 2\images/image_part_009.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 3\images/image_part_001.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 3\images/image_part_002.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 3\images/image_part_003.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 3\images/image_part_004.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 3\images/image_part_005.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 3\images/image_part_006.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 3\images/image_part_007.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 3\images/image_part_008.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 3\images/image_part_009.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 4\images/image_part_001.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 4\images/image_part_002.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 4\images/image_part_003.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 4\images/image_part_004.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 4\images/image_part_005.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 4\images/image_part_006.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 4\images/image_part_007.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 4\images/image_part_008.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 4\images/image_part_009.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 5\images/image_part_001.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 5\images/image_part_002.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 5\images/image_part_003.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 5\images/image_part_004.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 5\images/image_part_005.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 5\images/image_part_006.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 5\images/image_part_007.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 5\images/image_part_008.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 5\images/image_part_009.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 6\images/image_part_001.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 6\images/image_part_002.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 6\images/image_part_003.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 6\images/image_part_004.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 6\images/image_part_005.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 6\images/image_part_006.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 6\images/image_part_007.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 6\images/image_part_008.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 6\images/image_part_009.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 7\images/image_part_001.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 7\images/image_part_002.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 7\images/image_part_003.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 7\images/image_part_004.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 7\images/image_part_005.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 7\images/image_part_006.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 7\images/image_part_007.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 7\images/image_part_008.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 7\images/image_part_009.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 8\images/image_part_001.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 8\images/image_part_002.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 8\images/image_part_003.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 8\images/image_part_004.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 8\images/image_part_005.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 8\images/image_part_006.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 8\images/image_part_007.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 8\images/image_part_008.jpg
# Now patchifying image: ./Semantic segmentation dataset\Tile 8\images/image_part_009.jpg

# %%
print(len(image_dataset))
# Out:
# 1305

# %%
# Doing the same as above for masks
mask_dataset = []  
for path, subdirs, files in os.walk(root_directory):
    # print(path)  
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'masks':   # Find all 'images' directories
        masks = sorted(os.listdir(path))  # List of all image names in this subdirectory
        for i, mask_name in enumerate(masks):  
            if mask_name.endswith(".png"):   # Only read png images... (masks in this dataset)
               
                mask = cv2.imread(path+"/"+mask_name, 1)  # Read each image as Grey (or color but remember to map each color to an integer)
                mask = cv2.cvtColor(mask,cv2.COLOR_BGR2RGB)
                SIZE_X = (mask.shape[1]//patch_size)*patch_size # Nearest size divisible by our patch size
                SIZE_Y = (mask.shape[0]//patch_size)*patch_size # Nearest size divisible by our patch size
                mask = Image.fromarray(mask)
                mask = mask.crop((0 ,0, SIZE_X, SIZE_Y))  # Crop from top left corner
                # mask = mask.resize((SIZE_X, SIZE_Y))  # Try not to resize for semantic segmentation
                mask = np.array(mask)             
       
                # Extract patches from each image
                print("Now patchifying mask:", path+"/"+mask_name)
                patches_mask = patchify(mask, (patch_size, patch_size, 3), step=patch_size)  #Step=256 for 256 patches means no overlap
        
                for i in range(patches_mask.shape[0]):
                    for j in range(patches_mask.shape[1]):
                        
                        single_patch_mask = patches_mask[i,j,:,:]
                        # single_patch_img = (single_patch_img.astype('float32')) / 255. #No need to scale masks, but you can do it if you want
                        single_patch_mask = single_patch_mask[0] # Drop the extra unecessary dimension that patchify adds.                               
                        mask_dataset.append(single_patch_mask) 
 
image_dataset = np.array(image_dataset)
mask_dataset =  np.array(mask_dataset)
# Out:
# Now patchifying mask: ./Semantic segmentation dataset\Tile 1\masks/image_part_001.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 1\masks/image_part_002.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 1\masks/image_part_003.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 1\masks/image_part_004.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 1\masks/image_part_005.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 1\masks/image_part_006.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 1\masks/image_part_007.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 1\masks/image_part_008.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 1\masks/image_part_009.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 2\masks/image_part_001.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 2\masks/image_part_002.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 2\masks/image_part_003.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 2\masks/image_part_004.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 2\masks/image_part_005.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 2\masks/image_part_006.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 2\masks/image_part_007.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 2\masks/image_part_008.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 2\masks/image_part_009.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 3\masks/image_part_001.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 3\masks/image_part_002.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 3\masks/image_part_003.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 3\masks/image_part_004.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 3\masks/image_part_005.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 3\masks/image_part_006.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 3\masks/image_part_007.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 3\masks/image_part_008.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 3\masks/image_part_009.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 4\masks/image_part_001.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 4\masks/image_part_002.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 4\masks/image_part_003.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 4\masks/image_part_004.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 4\masks/image_part_005.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 4\masks/image_part_006.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 4\masks/image_part_007.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 4\masks/image_part_008.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 4\masks/image_part_009.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 5\masks/image_part_001.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 5\masks/image_part_002.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 5\masks/image_part_003.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 5\masks/image_part_004.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 5\masks/image_part_005.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 5\masks/image_part_006.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 5\masks/image_part_007.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 5\masks/image_part_008.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 5\masks/image_part_009.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 6\masks/image_part_001.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 6\masks/image_part_002.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 6\masks/image_part_003.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 6\masks/image_part_004.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 6\masks/image_part_005.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 6\masks/image_part_006.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 6\masks/image_part_007.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 6\masks/image_part_008.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 6\masks/image_part_009.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 7\masks/image_part_001.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 7\masks/image_part_002.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 7\masks/image_part_003.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 7\masks/image_part_004.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 7\masks/image_part_005.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 7\masks/image_part_006.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 7\masks/image_part_007.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 7\masks/image_part_008.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 7\masks/image_part_009.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 8\masks/image_part_001.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 8\masks/image_part_002.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 8\masks/image_part_003.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 8\masks/image_part_004.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 8\masks/image_part_005.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 8\masks/image_part_006.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 8\masks/image_part_007.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 8\masks/image_part_008.png
# Now patchifying mask: ./Semantic segmentation dataset\Tile 8\masks/image_part_009.png

# %%
# Sanity check, view a few images
import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(image_dataset[image_number], (patch_size, patch_size, 3)))
plt.subplot(122)
plt.imshow(np.reshape(mask_dataset[image_number], (patch_size, patch_size, 3)))
plt.show()

# %%
# Convert HEX to RGB array
# Try the following to understand how python handles hex values...
a=int('3C', 16)  # 3C with base 16. Should return 60. 
print(a)
# Do the same for all RGB channels in each hex code to convert to RGB
Building = '#3C1098'.lstrip('#')
Building = np.array(tuple(int(Building[i:i+2], 16) for i in (0, 2, 4))) # 60, 16, 152

Land = '#8429F6'.lstrip('#')
Land = np.array(tuple(int(Land[i:i+2], 16) for i in (0, 2, 4))) #132, 41, 246

Road = '#6EC1E4'.lstrip('#') 
Road = np.array(tuple(int(Road[i:i+2], 16) for i in (0, 2, 4))) #110, 193, 228

Vegetation =  'FEDD3A'.lstrip('#') 
Vegetation = np.array(tuple(int(Vegetation[i:i+2], 16) for i in (0, 2, 4))) #254, 221, 58

Water = 'E2A929'.lstrip('#') 
Water = np.array(tuple(int(Water[i:i+2], 16) for i in (0, 2, 4))) #226, 169, 41

Unlabeled = '#9B9B9B'.lstrip('#') 
Unlabeled = np.array(tuple(int(Unlabeled[i:i+2], 16) for i in (0, 2, 4))) #155, 155, 155

label = single_patch_mask
# Out:
# 60

# %%
# Now replace RGB to integer values to be used as labels.
# Find pixels with combination of RGB for the above defined arrays...
# if matches then replace all values in that pixel with a specific integer
def rgb_to_2D_label(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    label_seg [np.all(label == Building,axis=-1)] = 0
    label_seg [np.all(label==Land,axis=-1)] = 1
    label_seg [np.all(label==Road,axis=-1)] = 2
    label_seg [np.all(label==Vegetation,axis=-1)] = 3
    label_seg [np.all(label==Water,axis=-1)] = 4
    label_seg [np.all(label==Unlabeled,axis=-1)] = 5
    
    label_seg = label_seg[:,:,0]  #Just take the first channel, no need for all 3 channels
    
    return label_seg

labels = []
for i in range(mask_dataset.shape[0]):
    label = rgb_to_2D_label(mask_dataset[i])
    labels.append(label)    

labels = np.array(labels)   
labels = np.expand_dims(labels, axis=3)

# %%
print("Unique labels in label dataset are: ", np.unique(labels))

# Another Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number])
plt.subplot(122)
plt.imshow(labels[image_number][:,:,0])
plt.show()
# Out:
# Unique labels in label dataset are:  [0 1 2 3 4 5]

# %%
n_classes = len(np.unique(labels))
from tensorflow.keras.utils import to_categorical
labels_cat = to_categorical(labels, num_classes=n_classes)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, labels_cat, test_size = 0.20, random_state = 42)

# %%
# Parameters for model
# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss
# from sklearn.utils.class_weight import compute_class_weight

# weights = compute_class_weight('balanced', np.unique(np.ravel(labels,order='C')), 
#                               np.ravel(labels,order='C'))
# print(weights)

weights = [0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]
dice_loss = sm.losses.DiceLoss(class_weights=weights) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)  #


IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras import layers
from tensorflow.keras import backend as K
import tensorflow.keras
import tensorflow as tf

def convolution_block(
    block_input,
    num_filters=256,
    kernel_size=3,
    dilation_rate=1,
    padding="same",
    use_bias=False,
):
    x = layers.Conv2D(
        num_filters,
        kernel_size=kernel_size,
        dilation_rate=dilation_rate,
        padding="same",
        use_bias=use_bias,
        kernel_initializer=tensorflow.keras.initializers.HeNormal(),
    )(block_input)
    x = layers.BatchNormalization()(x)
    return tf.nn.relu(x)


def DilatedSpatialPyramidPooling(dspp_input):
    dims = dspp_input.shape
    x = layers.AveragePooling2D(pool_size=(dims[-3], dims[-2]))(dspp_input)
    x = convolution_block(x, kernel_size=1, use_bias=True)
    out_pool = layers.UpSampling2D(
        size=(dims[-3] // x.shape[1], dims[-2] // x.shape[2]), interpolation="bilinear",
    )(x)

    out_1 = convolution_block(dspp_input, kernel_size=1, dilation_rate=1)
    out_6 = convolution_block(dspp_input, kernel_size=3, dilation_rate=6)
    out_12 = convolution_block(dspp_input, kernel_size=3, dilation_rate=12)
    out_18 = convolution_block(dspp_input, kernel_size=3, dilation_rate=18)

    x = layers.Concatenate(axis=-1)([out_pool, out_1, out_6, out_12, out_18])
    output = convolution_block(x, kernel_size=1)
    return output

# %%
'''
from tensorflow.keras.applications.resnet import ResNet50

IMAGE_SIZE = 256 # Assume square
NUM_CLASSES = 6

def DeeplabV3Plus(image_size, num_classes):
    model_input = tensorflow.keras.Input(shape=(image_size, image_size, 3))
    resnet50 = ResNet50(
        weights="imagenet", include_top=False, input_tensor=model_input
    )
    x = resnet50.get_layer("conv4_block6_2_relu").output
    x = DilatedSpatialPyramidPooling(x)

    input_a = layers.UpSampling2D(
        size=(image_size // 4 // x.shape[1], image_size // 4 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    input_b = resnet50.get_layer("conv2_block3_2_relu").output
    input_b = convolution_block(input_b, num_filters=48, kernel_size=1)

    x = layers.Concatenate(axis=-1)([input_a, input_b])
    x = convolution_block(x)
    x = convolution_block(x)
    x = layers.UpSampling2D(
        size=(image_size // x.shape[1], image_size // x.shape[2]),
        interpolation="bilinear",
    )(x)
    model_output = layers.Conv2D(num_classes, kernel_size=(1, 1), padding="same")(x)
    return tensorflow.keras.Model(inputs=model_input, outputs=model_output)

model = DeeplabV3Plus(image_size=IMAGE_SIZE, num_classes=NUM_CLASSES)
model.summary()
'''
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.applications import ResNet50

IMAGE_SIZE = 256  # Assume square
NUM_CLASSES = 6

def convolution_block(block_input, num_filters=32, kernel_size=3, padding='same', use_bias=False, dilation_rate=1):
    x = layers.Conv2D(
        num_filters,
        kernel_size=kernel_size,
        padding=padding,
        use_bias=use_bias,
        dilation_rate=dilation_rate,
        kernel_initializer=tf.keras.initializers.HeNormal(),
    )(block_input)
    x = layers.BatchNormalization()(x)
    return layers.ReLU()(x)

def DilatedSpatialPyramidPooling(dspp_input):
    dims = dspp_input.shape
    x = layers.AveragePooling2D(pool_size=(dims[1], dims[2]))(dspp_input)
    x = convolution_block(x, num_filters=128, kernel_size=1, use_bias=True)
    
    out_pool = layers.UpSampling2D(size=(dims[1] // x.shape[1], dims[2] // x.shape[2]), interpolation="bilinear")(x)
    
    out_1 = convolution_block(dspp_input, num_filters=128, kernel_size=1, dilation_rate=1)
    out_2 = convolution_block(dspp_input, num_filters=128, kernel_size=3, dilation_rate=2)
    out_3 = convolution_block(dspp_input, num_filters=128, kernel_size=3, dilation_rate=4)
    
    out_1 = layers.UpSampling2D(size=(dims[1] // out_1.shape[1], dims[2] // out_1.shape[2]), interpolation="bilinear")(out_1)
    out_2 = layers.UpSampling2D(size=(dims[1] // out_2.shape[1], dims[2] // out_2.shape[2]), interpolation="bilinear")(out_2)
    out_3 = layers.UpSampling2D(size=(dims[1] // out_3.shape[1], dims[2] // out_3.shape[2]), interpolation="bilinear")(out_3)
    
    x = layers.Concatenate(axis=-1)([out_pool, out_1, out_2, out_3])
    return convolution_block(x, num_filters=128, kernel_size=1)

def DeeplabV3Plus(image_size, num_classes):
    model_input = layers.Input(shape=(image_size, image_size, 3))
    resnet50 = ResNet50(weights="imagenet", include_top=False, input_tensor=model_input)
    
    x = resnet50.get_layer("conv4_block6_2_relu").output
    x = DilatedSpatialPyramidPooling(x)

    input_a = layers.UpSampling2D(
        size=(image_size // 4 // x.shape[1], image_size // 4 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    input_b = resnet50.get_layer("conv2_block3_2_relu").output
    input_b = convolution_block(input_b, num_filters=48, kernel_size=1)

    x = layers.Concatenate(axis=-1)([input_a, input_b])
    x = convolution_block(x)
    x = convolution_block(x)
    x = layers.UpSampling2D(
        size=(image_size // x.shape[1], image_size // x.shape[2]),
        interpolation="bilinear",
    )(x)
    model_output = layers.Conv2D(num_classes, kernel_size=(1, 1), padding="same")(x)
    
    return tf.keras.Model(inputs=model_input, outputs=model_output)

model = DeeplabV3Plus(image_size=IMAGE_SIZE, num_classes=NUM_CLASSES)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 262, 262,  │          0 │ input_layer_2[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 128, 128,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 128, 128,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 128, 128,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 130, 130,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 64, 64,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 64, 64,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 64, 64,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 64, 64,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 64, 64,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 64, 64,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 64, 64,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 64, 64,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 64, 64,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 64, 64,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 64, 64,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 64, 64,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 64, 64,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 64, 64,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 64, 64,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 64, 64,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 64, 64,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 64, 64,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 64, 64,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 64, 64,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 64, 64,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 64, 64,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 64, 64,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 64, 64,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 64, 64,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 64, 64,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 64, 64,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 64, 64,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 64, 64,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 64, 64,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 64, 64,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 64, 64,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 64, 64,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 32, 32,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 32, 32,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 32, 32,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 32, 32,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 32, 32,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 32, 32,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 32, 32,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 32, 32,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 32, 32,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 32, 32,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 32, 32,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 32, 32,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 32, 32,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 32, 32,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 32, 32,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 32, 32,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 32, 32,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 32, 32,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 32, 32,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 32, 32,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 32, 32,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 32, 32,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 32, 32,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 32, 32,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 32, 32,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 32, 32,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 32, 32,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 32, 32,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 32, 32,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 32, 32,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 32, 32,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 32, 32,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 32, 32,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 32, 32,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 32, 32,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 32, 32,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 32, 32,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 32, 32,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 32, 32,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 32, 32,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 32, 32,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 32, 32,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 16, 16,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 16, 16,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 16, 16,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 16, 16,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 16, 16,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 16, 16,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 16, 16,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 16, 16,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 16, 16,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 16, 16,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 16, 16,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 16, 16,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 16, 16,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 16, 16,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 16, 16,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 16, 16,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 16, 16,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 16, 16,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 16, 16,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 16, 16,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 16, 16,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 16, 16,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 16, 16,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 16, 16,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 16, 16,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 16, 16,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 16, 16,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 16, 16,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 16, 16,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 16, 16,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 16, 16,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 16, 16,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 16, 16,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 16, 16,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 16, 16,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 16, 16,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 16, 16,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 16, 16,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 16, 16,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 16, 16,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 16, 16,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 16, 16,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 16, 16,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 16, 16,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 16, 16,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 16, 16,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_2 │ (None, 1, 1, 256) │          0 │ conv4_block6_2_r… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 1, 1, 128) │     32,896 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │     32,768 │ conv4_block6_2_r… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │    294,912 │ conv4_block6_2_r… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 16, 16,    │    294,912 │ conv4_block6_2_r… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1, 128) │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 1, 1, 128) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 16, 16,    │          0 │ re_lu_1[0][0]     │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 16, 16,    │          0 │ re_lu_2[0][0]     │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 16, 16,    │          0 │ re_lu_3[0][0]     │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 16, 16,    │          0 │ re_lu_4[0][0]     │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 512)              │            │ up_sampling2d_2[… │
# │                     │                   │            │ up_sampling2d_3[… │
# │                     │                   │            │ up_sampling2d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │     65,536 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │      3,072 │ conv2_block3_2_r… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 64, 64,    │          0 │ re_lu_5[0][0]     │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ up_sampling2d_5[… │
# │ (Concatenate)       │ 176)              │            │ re_lu_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │     50,688 │ concatenate_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │      9,216 │ re_lu_7[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 256, 256,  │          0 │ re_lu_8[0][0]     │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 256, 256,  │        198 │ up_sampling2d_6[… │
# │                     │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,109,126 (34.75 MB)
#  Trainable params: 9,079,078 (34.63 MB)
#  Non-trainable params: 30,048 (117.38 KB)

# %%
'''
sm.set_framework('tf.keras')
BACKBONE = 'resnet50'
preprocess_input = sm.get_preprocessing(BACKBONE)

# preprocess input
X_train_prepr = preprocess_input(X_train)
X_test_prepr = preprocess_input(X_test)

print(X_train_prepr.shape)
print(y_train.shape)

def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

callbacks = [
             tensorflow.keras.callbacks.ModelCheckpoint(
                os.path.join("./weights", "weights.04-deeplabv3.{epoch:03d}.hdf5"), 
                save_best_only=False,
                save_weights_only=True,
                verbose=1
              ),
            ]

loss = tensorflow.keras.losses.CategoricalCrossentropy(from_logits=True)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=loss,
    metrics=["accuracy", jacard_coef]
)

history = model.fit(X_train_prepr, 
          y_train,
          batch_size=4, 
          epochs=100,
          validation_data=(X_test_prepr, y_test),
          verbose=1,
      callbacks=callbacks        )

model.save('./models/unet_with_deeplabv3+_backbone_100epochs.hdf5')

plt.plot(history.history["loss"])
plt.title("Training Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["accuracy"])
plt.title("Training Accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["val_loss"])
plt.title("Validation Loss")
plt.ylabel("val_loss")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["val_accuracy"])
plt.title("Validation Accuracy")
plt.ylabel("val_accuracy")
plt.xlabel("epoch")
plt.show()
'''
import os
import tensorflow as tf
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt

# Assuming you have your data preprocessed as X_train_prepr and y_train

def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        os.path.join("./weights", "weights.04-deeplabv3.{epoch:03d}.weights.h5"), 
        save_best_only=False,
        save_weights_only=True,
        verbose=1
    ),
]

loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=loss,
    metrics=["accuracy", jacard_coef]
)

history = model.fit(
    X_train_prepr, 
    y_train,
    batch_size=4, 
    epochs=100,
    validation_data=(X_test_prepr, y_test),
    verbose=1,
    callbacks=callbacks
)

model.save('./models/unet_with_deeplabv3+_backbone_100epochs.hdf5')

# Plotting training and validation metrics
plt.plot(history.history["loss"])
plt.title("Training Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["accuracy"])
plt.title("Training Accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["val_loss"])
plt.title("Validation Loss")
plt.ylabel("val_loss")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["val_accuracy"])
plt.title("Validation Accuracy")
plt.ylabel("val_accuracy")
plt.xlabel("epoch")
plt.show()
# Out:
# Epoch 1/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.6205 - jacard_coef: -0.9419 - loss: 1.1391
# Epoch 1: saving model to ./weights\weights.04-deeplabv3.001.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 122s 377ms/step - accuracy: 0.6208 - jacard_coef: -0.9425 - loss: 1.1383 - val_accuracy: 0.5364 - val_jacard_coef: -0.4497 - val_loss: 2.2894
# Epoch 2/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.7664 - jacard_coef: -0.7201 - loss: 0.7005
# Epoch 2: saving model to ./weights\weights.04-deeplabv3.002.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 100s 383ms/step - accuracy: 0.7664 - jacard_coef: -0.7199 - loss: 0.7005 - val_accuracy: 0.5319 - val_jacard_coef: 0.1660 - val_loss: 18.0893
# Epoch 3/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.7828 - jacard_coef: -0.5875 - loss: 0.6404
# Epoch 3: saving model to ./weights\weights.04-deeplabv3.003.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 103s 396ms/step - accuracy: 0.7828 - jacard_coef: -0.5874 - loss: 0.6403 - val_accuracy: 0.5394 - val_jacard_coef: -0.4510 - val_loss: 1.6654
# Epoch 4/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.7995 - jacard_coef: -0.5306 - loss: 0.6006
# Epoch 4: saving model to ./weights\weights.04-deeplabv3.004.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 108s 413ms/step - accuracy: 0.7995 - jacard_coef: -0.5306 - loss: 0.6006 - val_accuracy: 0.7808 - val_jacard_coef: -0.5560 - val_loss: 0.6862
# Epoch 5/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.8147 - jacard_coef: -0.4982 - loss: 0.5618
# Epoch 5: saving model to ./weights\weights.04-deeplabv3.005.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 428ms/step - accuracy: 0.8146 - jacard_coef: -0.4982 - loss: 0.5618 - val_accuracy: 0.2813 - val_jacard_coef: -0.3856 - val_loss: 1.6883
# Epoch 6/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8252 - jacard_coef: -0.4781 - loss: 0.5141
# Epoch 6: saving model to ./weights\weights.04-deeplabv3.006.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 114s 438ms/step - accuracy: 0.8252 - jacard_coef: -0.4781 - loss: 0.5141 - val_accuracy: 0.8371 - val_jacard_coef: -0.4482 - val_loss: 0.4933
# Epoch 7/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.8155 - jacard_coef: -0.4526 - loss: 0.5445
# Epoch 7: saving model to ./weights\weights.04-deeplabv3.007.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 441ms/step - accuracy: 0.8155 - jacard_coef: -0.4526 - loss: 0.5445 - val_accuracy: 0.6989 - val_jacard_coef: -0.2740 - val_loss: 1.7243
# Epoch 8/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8169 - jacard_coef: -0.4411 - loss: 0.5362
# Epoch 8: saving model to ./weights\weights.04-deeplabv3.008.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 114s 438ms/step - accuracy: 0.8170 - jacard_coef: -0.4411 - loss: 0.5362 - val_accuracy: 0.7595 - val_jacard_coef: -0.3297 - val_loss: 0.7519
# Epoch 9/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.8191 - jacard_coef: -0.4234 - loss: 0.5346
# Epoch 9: saving model to ./weights\weights.04-deeplabv3.009.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 110s 422ms/step - accuracy: 0.8192 - jacard_coef: -0.4234 - loss: 0.5346 - val_accuracy: 0.7693 - val_jacard_coef: -0.4385 - val_loss: 0.6761
# Epoch 10/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8371 - jacard_coef: -0.4228 - loss: 0.4835
# Epoch 10: saving model to ./weights\weights.04-deeplabv3.010.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 434ms/step - accuracy: 0.8371 - jacard_coef: -0.4227 - loss: 0.4835 - val_accuracy: 0.7696 - val_jacard_coef: -0.4349 - val_loss: 0.7586
# Epoch 11/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8282 - jacard_coef: -0.4113 - loss: 0.4986
# Epoch 11: saving model to ./weights\weights.04-deeplabv3.011.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 430ms/step - accuracy: 0.8282 - jacard_coef: -0.4113 - loss: 0.4986 - val_accuracy: 0.8386 - val_jacard_coef: -0.3462 - val_loss: 0.4503
# Epoch 12/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8359 - jacard_coef: -0.4013 - loss: 0.4762
# Epoch 12: saving model to ./weights\weights.04-deeplabv3.012.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 433ms/step - accuracy: 0.8359 - jacard_coef: -0.4012 - loss: 0.4762 - val_accuracy: 0.7972 - val_jacard_coef: -0.3915 - val_loss: 0.5626
# Epoch 13/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.8400 - jacard_coef: -0.3893 - loss: 0.4626
# Epoch 13: saving model to ./weights\weights.04-deeplabv3.013.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 144s 441ms/step - accuracy: 0.8400 - jacard_coef: -0.3893 - loss: 0.4626 - val_accuracy: 0.8269 - val_jacard_coef: -0.2911 - val_loss: 0.5225
# Epoch 14/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.8391 - jacard_coef: -0.3892 - loss: 0.4627
# Epoch 14: saving model to ./weights\weights.04-deeplabv3.014.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 440ms/step - accuracy: 0.8391 - jacard_coef: -0.3892 - loss: 0.4627 - val_accuracy: 0.6345 - val_jacard_coef: -0.0997 - val_loss: 1.3810
# Epoch 15/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8255 - jacard_coef: -0.3797 - loss: 0.5114
# Epoch 15: saving model to ./weights\weights.04-deeplabv3.015.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 427ms/step - accuracy: 0.8256 - jacard_coef: -0.3798 - loss: 0.5113 - val_accuracy: 0.8440 - val_jacard_coef: -0.3807 - val_loss: 0.4351
# Epoch 16/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8485 - jacard_coef: -0.3780 - loss: 0.4375
# Epoch 16: saving model to ./weights\weights.04-deeplabv3.016.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 432ms/step - accuracy: 0.8485 - jacard_coef: -0.3779 - loss: 0.4376 - val_accuracy: 0.6003 - val_jacard_coef: -0.3458 - val_loss: 0.8014
# Epoch 17/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.8360 - jacard_coef: -0.3703 - loss: 0.4613
# Epoch 17: saving model to ./weights\weights.04-deeplabv3.017.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 425ms/step - accuracy: 0.8360 - jacard_coef: -0.3703 - loss: 0.4612 - val_accuracy: 0.8371 - val_jacard_coef: -0.3792 - val_loss: 0.4849
# Epoch 18/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8430 - jacard_coef: -0.3619 - loss: 0.4665
# Epoch 18: saving model to ./weights\weights.04-deeplabv3.018.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 424ms/step - accuracy: 0.8430 - jacard_coef: -0.3619 - loss: 0.4665 - val_accuracy: 0.8526 - val_jacard_coef: -0.3592 - val_loss: 0.4176
# Epoch 19/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8592 - jacard_coef: -0.3611 - loss: 0.4094
# Epoch 19: saving model to ./weights\weights.04-deeplabv3.019.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 110s 423ms/step - accuracy: 0.8591 - jacard_coef: -0.3611 - loss: 0.4095 - val_accuracy: 0.7934 - val_jacard_coef: -0.2921 - val_loss: 0.5440
# Epoch 20/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8535 - jacard_coef: -0.3515 - loss: 0.4281
# Epoch 20: saving model to ./weights\weights.04-deeplabv3.020.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 424ms/step - accuracy: 0.8535 - jacard_coef: -0.3515 - loss: 0.4282 - val_accuracy: 0.8067 - val_jacard_coef: -0.2888 - val_loss: 0.6652
# Epoch 21/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8488 - jacard_coef: -0.3492 - loss: 0.4334
# Epoch 21: saving model to ./weights\weights.04-deeplabv3.021.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 114s 438ms/step - accuracy: 0.8488 - jacard_coef: -0.3492 - loss: 0.4334 - val_accuracy: 0.7660 - val_jacard_coef: -0.3188 - val_loss: 0.6516
# Epoch 22/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8626 - jacard_coef: -0.3472 - loss: 0.3877
# Epoch 22: saving model to ./weights\weights.04-deeplabv3.022.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 434ms/step - accuracy: 0.8626 - jacard_coef: -0.3472 - loss: 0.3878 - val_accuracy: 0.8284 - val_jacard_coef: -0.3342 - val_loss: 0.5204
# Epoch 23/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.8597 - jacard_coef: -0.3371 - loss: 0.4005
# Epoch 23: saving model to ./weights\weights.04-deeplabv3.023.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 428ms/step - accuracy: 0.8596 - jacard_coef: -0.3371 - loss: 0.4006 - val_accuracy: 0.8000 - val_jacard_coef: -0.2848 - val_loss: 0.6590
# Epoch 24/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.8536 - jacard_coef: -0.3368 - loss: 0.4187
# Epoch 24: saving model to ./weights\weights.04-deeplabv3.024.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 428ms/step - accuracy: 0.8536 - jacard_coef: -0.3368 - loss: 0.4187 - val_accuracy: 0.8233 - val_jacard_coef: -0.2907 - val_loss: 0.5032
# Epoch 25/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.8587 - jacard_coef: -0.3271 - loss: 0.3993
# Epoch 25: saving model to ./weights\weights.04-deeplabv3.025.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 429ms/step - accuracy: 0.8588 - jacard_coef: -0.3271 - loss: 0.3993 - val_accuracy: 0.8580 - val_jacard_coef: -0.2825 - val_loss: 0.4133
# Epoch 26/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.8656 - jacard_coef: -0.3224 - loss: 0.3763
# Epoch 26: saving model to ./weights\weights.04-deeplabv3.026.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 428ms/step - accuracy: 0.8656 - jacard_coef: -0.3224 - loss: 0.3764 - val_accuracy: 0.3506 - val_jacard_coef: -0.2662 - val_loss: 1.5040
# Epoch 27/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8608 - jacard_coef: -0.3195 - loss: 0.3919
# Epoch 27: saving model to ./weights\weights.04-deeplabv3.027.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 435ms/step - accuracy: 0.8608 - jacard_coef: -0.3195 - loss: 0.3919 - val_accuracy: 0.8397 - val_jacard_coef: -0.3266 - val_loss: 0.4670
# Epoch 28/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.8623 - jacard_coef: -0.3234 - loss: 0.3894
# Epoch 28: saving model to ./weights\weights.04-deeplabv3.028.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 428ms/step - accuracy: 0.8623 - jacard_coef: -0.3234 - loss: 0.3894 - val_accuracy: 0.7327 - val_jacard_coef: -0.2731 - val_loss: 0.6747
# Epoch 29/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8732 - jacard_coef: -0.3162 - loss: 0.3627
# Epoch 29: saving model to ./weights\weights.04-deeplabv3.029.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 430ms/step - accuracy: 0.8731 - jacard_coef: -0.3162 - loss: 0.3627 - val_accuracy: 0.8681 - val_jacard_coef: -0.2984 - val_loss: 0.3884
# Epoch 30/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8691 - jacard_coef: -0.3151 - loss: 0.3681
# Epoch 30: saving model to ./weights\weights.04-deeplabv3.030.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 114s 438ms/step - accuracy: 0.8692 - jacard_coef: -0.3151 - loss: 0.3681 - val_accuracy: 0.7410 - val_jacard_coef: -0.2907 - val_loss: 0.7405
# Epoch 31/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8742 - jacard_coef: -0.3115 - loss: 0.3570
# Epoch 31: saving model to ./weights\weights.04-deeplabv3.031.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 426ms/step - accuracy: 0.8742 - jacard_coef: -0.3114 - loss: 0.3570 - val_accuracy: 0.8578 - val_jacard_coef: -0.2753 - val_loss: 0.4170
# Epoch 32/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.8720 - jacard_coef: -0.3085 - loss: 0.3553
# Epoch 32: saving model to ./weights\weights.04-deeplabv3.032.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 426ms/step - accuracy: 0.8720 - jacard_coef: -0.3085 - loss: 0.3553 - val_accuracy: 0.6558 - val_jacard_coef: -0.2515 - val_loss: 1.3060
# Epoch 33/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.8842 - jacard_coef: -0.3078 - loss: 0.3278
# Epoch 33: saving model to ./weights\weights.04-deeplabv3.033.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 425ms/step - accuracy: 0.8842 - jacard_coef: -0.3077 - loss: 0.3278 - val_accuracy: 0.8572 - val_jacard_coef: -0.3056 - val_loss: 0.4323
# Epoch 34/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.8860 - jacard_coef: -0.3047 - loss: 0.3220
# Epoch 34: saving model to ./weights\weights.04-deeplabv3.034.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 428ms/step - accuracy: 0.8860 - jacard_coef: -0.3046 - loss: 0.3221 - val_accuracy: 0.6250 - val_jacard_coef: -0.2256 - val_loss: 1.1561
# Epoch 35/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.8723 - jacard_coef: -0.2970 - loss: 0.3586
# Epoch 35: saving model to ./weights\weights.04-deeplabv3.035.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 428ms/step - accuracy: 0.8723 - jacard_coef: -0.2970 - loss: 0.3586 - val_accuracy: 0.8158 - val_jacard_coef: -0.2287 - val_loss: 0.5455
# Epoch 36/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.8742 - jacard_coef: -0.2906 - loss: 0.3548
# Epoch 36: saving model to ./weights\weights.04-deeplabv3.036.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 428ms/step - accuracy: 0.8743 - jacard_coef: -0.2906 - loss: 0.3547 - val_accuracy: 0.6732 - val_jacard_coef: -0.2680 - val_loss: 1.0553
# Epoch 37/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8806 - jacard_coef: -0.2914 - loss: 0.3342
# Epoch 37: saving model to ./weights\weights.04-deeplabv3.037.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 114s 435ms/step - accuracy: 0.8806 - jacard_coef: -0.2914 - loss: 0.3342 - val_accuracy: 0.6252 - val_jacard_coef: -0.2912 - val_loss: 0.8060
# Epoch 38/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8870 - jacard_coef: -0.2923 - loss: 0.3119
# Epoch 38: saving model to ./weights\weights.04-deeplabv3.038.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 114s 435ms/step - accuracy: 0.8870 - jacard_coef: -0.2922 - loss: 0.3119 - val_accuracy: 0.8629 - val_jacard_coef: -0.2803 - val_loss: 0.4011
# Epoch 39/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8932 - jacard_coef: -0.2851 - loss: 0.2984
# Epoch 39: saving model to ./weights\weights.04-deeplabv3.039.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 426ms/step - accuracy: 0.8931 - jacard_coef: -0.2851 - loss: 0.2985 - val_accuracy: 0.8303 - val_jacard_coef: -0.2583 - val_loss: 0.5329
# Epoch 40/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.8975 - jacard_coef: -0.2843 - loss: 0.2888
# Epoch 40: saving model to ./weights\weights.04-deeplabv3.040.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 425ms/step - accuracy: 0.8975 - jacard_coef: -0.2843 - loss: 0.2888 - val_accuracy: 0.8605 - val_jacard_coef: -0.2519 - val_loss: 0.4197
# Epoch 41/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8945 - jacard_coef: -0.2806 - loss: 0.2885
# Epoch 41: saving model to ./weights\weights.04-deeplabv3.041.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 433ms/step - accuracy: 0.8945 - jacard_coef: -0.2806 - loss: 0.2885 - val_accuracy: 0.6465 - val_jacard_coef: -0.2394 - val_loss: 0.8536
# Epoch 42/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.9032 - jacard_coef: -0.2793 - loss: 0.2669
# Epoch 42: saving model to ./weights\weights.04-deeplabv3.042.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 443ms/step - accuracy: 0.9032 - jacard_coef: -0.2793 - loss: 0.2669 - val_accuracy: 0.8276 - val_jacard_coef: -0.2506 - val_loss: 0.4895
# Epoch 43/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.8975 - jacard_coef: -0.2745 - loss: 0.2832
# Epoch 43: saving model to ./weights\weights.04-deeplabv3.043.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 432ms/step - accuracy: 0.8975 - jacard_coef: -0.2745 - loss: 0.2832 - val_accuracy: 0.8477 - val_jacard_coef: -0.2364 - val_loss: 0.4480
# Epoch 44/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.8964 - jacard_coef: -0.2709 - loss: 0.2854
# Epoch 44: saving model to ./weights\weights.04-deeplabv3.044.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 425ms/step - accuracy: 0.8964 - jacard_coef: -0.2709 - loss: 0.2854 - val_accuracy: 0.7801 - val_jacard_coef: -0.2359 - val_loss: 0.6025
# Epoch 45/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.8999 - jacard_coef: -0.2663 - loss: 0.2753
# Epoch 45: saving model to ./weights\weights.04-deeplabv3.045.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 425ms/step - accuracy: 0.8999 - jacard_coef: -0.2663 - loss: 0.2753 - val_accuracy: 0.8426 - val_jacard_coef: -0.2458 - val_loss: 0.5190
# Epoch 46/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9009 - jacard_coef: -0.2697 - loss: 0.2752
# Epoch 46: saving model to ./weights\weights.04-deeplabv3.046.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 140s 417ms/step - accuracy: 0.9009 - jacard_coef: -0.2697 - loss: 0.2752 - val_accuracy: 0.8410 - val_jacard_coef: -0.2199 - val_loss: 0.4816
# Epoch 47/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9124 - jacard_coef: -0.2643 - loss: 0.2417
# Epoch 47: saving model to ./weights\weights.04-deeplabv3.047.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 110s 421ms/step - accuracy: 0.9124 - jacard_coef: -0.2643 - loss: 0.2418 - val_accuracy: 0.6833 - val_jacard_coef: -0.2146 - val_loss: 0.7865
# Epoch 48/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.9174 - jacard_coef: -0.2673 - loss: 0.2258
# Epoch 48: saving model to ./weights\weights.04-deeplabv3.048.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 110s 420ms/step - accuracy: 0.9174 - jacard_coef: -0.2673 - loss: 0.2258 - val_accuracy: 0.8589 - val_jacard_coef: -0.2364 - val_loss: 0.4546
# Epoch 49/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9118 - jacard_coef: -0.2632 - loss: 0.2450
# Epoch 49: saving model to ./weights\weights.04-deeplabv3.049.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 110s 422ms/step - accuracy: 0.9118 - jacard_coef: -0.2632 - loss: 0.2450 - val_accuracy: 0.8664 - val_jacard_coef: -0.2472 - val_loss: 0.4078
# Epoch 50/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9198 - jacard_coef: -0.2631 - loss: 0.2212
# Epoch 50: saving model to ./weights\weights.04-deeplabv3.050.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 424ms/step - accuracy: 0.9198 - jacard_coef: -0.2631 - loss: 0.2213 - val_accuracy: 0.6801 - val_jacard_coef: -0.2413 - val_loss: 0.8549
# Epoch 51/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9133 - jacard_coef: -0.2566 - loss: 0.2341
# Epoch 51: saving model to ./weights\weights.04-deeplabv3.051.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 110s 421ms/step - accuracy: 0.9133 - jacard_coef: -0.2566 - loss: 0.2341 - val_accuracy: 0.8011 - val_jacard_coef: -0.1857 - val_loss: 0.6415
# Epoch 52/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9051 - jacard_coef: -0.2493 - loss: 0.2581
# Epoch 52: saving model to ./weights\weights.04-deeplabv3.052.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 425ms/step - accuracy: 0.9051 - jacard_coef: -0.2493 - loss: 0.2580 - val_accuracy: 0.8682 - val_jacard_coef: -0.2470 - val_loss: 0.4122
# Epoch 53/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9204 - jacard_coef: -0.2532 - loss: 0.2138
# Epoch 53: saving model to ./weights\weights.04-deeplabv3.053.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 110s 422ms/step - accuracy: 0.9204 - jacard_coef: -0.2532 - loss: 0.2138 - val_accuracy: 0.8606 - val_jacard_coef: -0.2379 - val_loss: 0.4347
# Epoch 54/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9269 - jacard_coef: -0.2593 - loss: 0.1945
# Epoch 54: saving model to ./weights\weights.04-deeplabv3.054.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 110s 422ms/step - accuracy: 0.9269 - jacard_coef: -0.2593 - loss: 0.1945 - val_accuracy: 0.8357 - val_jacard_coef: -0.2224 - val_loss: 0.4781
# Epoch 55/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9269 - jacard_coef: -0.2524 - loss: 0.1969
# Epoch 55: saving model to ./weights\weights.04-deeplabv3.055.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 426ms/step - accuracy: 0.9269 - jacard_coef: -0.2524 - loss: 0.1969 - val_accuracy: 0.8407 - val_jacard_coef: -0.2408 - val_loss: 0.5093
# Epoch 56/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9118 - jacard_coef: -0.2444 - loss: 0.2406
# Epoch 56: saving model to ./weights\weights.04-deeplabv3.056.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 425ms/step - accuracy: 0.9118 - jacard_coef: -0.2444 - loss: 0.2406 - val_accuracy: 0.8366 - val_jacard_coef: -0.2306 - val_loss: 0.5046
# Epoch 57/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9166 - jacard_coef: -0.2447 - loss: 0.2245
# Epoch 57: saving model to ./weights\weights.04-deeplabv3.057.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 110s 421ms/step - accuracy: 0.9166 - jacard_coef: -0.2447 - loss: 0.2244 - val_accuracy: 0.8444 - val_jacard_coef: -0.2373 - val_loss: 0.4743
# Epoch 58/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.9284 - jacard_coef: -0.2422 - loss: 0.1919
# Epoch 58: saving model to ./weights\weights.04-deeplabv3.058.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 114s 438ms/step - accuracy: 0.9284 - jacard_coef: -0.2422 - loss: 0.1919 - val_accuracy: 0.8688 - val_jacard_coef: -0.2210 - val_loss: 0.4125
# Epoch 59/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.9311 - jacard_coef: -0.2403 - loss: 0.1859
# Epoch 59: saving model to ./weights\weights.04-deeplabv3.059.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 116s 445ms/step - accuracy: 0.9311 - jacard_coef: -0.2403 - loss: 0.1859 - val_accuracy: 0.8475 - val_jacard_coef: -0.2189 - val_loss: 0.4797
# Epoch 60/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.9323 - jacard_coef: -0.2403 - loss: 0.1801
# Epoch 60: saving model to ./weights\weights.04-deeplabv3.060.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 442ms/step - accuracy: 0.9323 - jacard_coef: -0.2403 - loss: 0.1801 - val_accuracy: 0.8685 - val_jacard_coef: -0.2311 - val_loss: 0.4264
# Epoch 61/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9367 - jacard_coef: -0.2380 - loss: 0.1691
# Epoch 61: saving model to ./weights\weights.04-deeplabv3.061.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 441ms/step - accuracy: 0.9367 - jacard_coef: -0.2380 - loss: 0.1691 - val_accuracy: 0.8486 - val_jacard_coef: -0.2046 - val_loss: 0.4727
# Epoch 62/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9389 - jacard_coef: -0.2342 - loss: 0.1610
# Epoch 62: saving model to ./weights\weights.04-deeplabv3.062.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 441ms/step - accuracy: 0.9389 - jacard_coef: -0.2342 - loss: 0.1611 - val_accuracy: 0.8715 - val_jacard_coef: -0.2026 - val_loss: 0.4228
# Epoch 63/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9400 - jacard_coef: -0.2342 - loss: 0.1579
# Epoch 63: saving model to ./weights\weights.04-deeplabv3.063.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 441ms/step - accuracy: 0.9400 - jacard_coef: -0.2342 - loss: 0.1579 - val_accuracy: 0.8569 - val_jacard_coef: -0.2266 - val_loss: 0.5329
# Epoch 64/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.9362 - jacard_coef: -0.2340 - loss: 0.1693
# Epoch 64: saving model to ./weights\weights.04-deeplabv3.064.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 114s 437ms/step - accuracy: 0.9362 - jacard_coef: -0.2340 - loss: 0.1693 - val_accuracy: 0.7353 - val_jacard_coef: -0.2152 - val_loss: 0.6500
# Epoch 65/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9416 - jacard_coef: -0.2347 - loss: 0.1529
# Epoch 65: saving model to ./weights\weights.04-deeplabv3.065.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 440ms/step - accuracy: 0.9415 - jacard_coef: -0.2347 - loss: 0.1530 - val_accuracy: 0.8533 - val_jacard_coef: -0.2112 - val_loss: 0.4786
# Epoch 66/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9345 - jacard_coef: -0.2274 - loss: 0.1778
# Epoch 66: saving model to ./weights\weights.04-deeplabv3.066.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 441ms/step - accuracy: 0.9345 - jacard_coef: -0.2274 - loss: 0.1779 - val_accuracy: 0.8672 - val_jacard_coef: -0.1953 - val_loss: 0.4329
# Epoch 67/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.9387 - jacard_coef: -0.2260 - loss: 0.1618
# Epoch 67: saving model to ./weights\weights.04-deeplabv3.067.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 439ms/step - accuracy: 0.9387 - jacard_coef: -0.2260 - loss: 0.1618 - val_accuracy: 0.8611 - val_jacard_coef: -0.2122 - val_loss: 0.4616
# Epoch 68/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.9403 - jacard_coef: -0.2231 - loss: 0.1580
# Epoch 68: saving model to ./weights\weights.04-deeplabv3.068.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 114s 438ms/step - accuracy: 0.9403 - jacard_coef: -0.2231 - loss: 0.1580 - val_accuracy: 0.8376 - val_jacard_coef: -0.1756 - val_loss: 0.5290
# Epoch 69/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9370 - jacard_coef: -0.2243 - loss: 0.1657
# Epoch 69: saving model to ./weights\weights.04-deeplabv3.069.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 136s 417ms/step - accuracy: 0.9370 - jacard_coef: -0.2243 - loss: 0.1656 - val_accuracy: 0.8614 - val_jacard_coef: -0.2074 - val_loss: 0.4726
# Epoch 70/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9463 - jacard_coef: -0.2250 - loss: 0.1399
# Epoch 70: saving model to ./weights\weights.04-deeplabv3.070.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 425ms/step - accuracy: 0.9463 - jacard_coef: -0.2250 - loss: 0.1399 - val_accuracy: 0.8648 - val_jacard_coef: -0.1953 - val_loss: 0.4664
# Epoch 71/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9495 - jacard_coef: -0.2252 - loss: 0.1317
# Epoch 71: saving model to ./weights\weights.04-deeplabv3.071.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 424ms/step - accuracy: 0.9495 - jacard_coef: -0.2252 - loss: 0.1317 - val_accuracy: 0.8718 - val_jacard_coef: -0.2005 - val_loss: 0.4482
# Epoch 72/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9488 - jacard_coef: -0.2199 - loss: 0.1332
# Epoch 72: saving model to ./weights\weights.04-deeplabv3.072.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 426ms/step - accuracy: 0.9487 - jacard_coef: -0.2199 - loss: 0.1332 - val_accuracy: 0.8601 - val_jacard_coef: -0.2108 - val_loss: 0.4993
# Epoch 73/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9051 - jacard_coef: -0.1996 - loss: 0.2728
# Epoch 73: saving model to ./weights\weights.04-deeplabv3.073.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 426ms/step - accuracy: 0.9051 - jacard_coef: -0.1996 - loss: 0.2727 - val_accuracy: 0.5104 - val_jacard_coef: -0.1310 - val_loss: 1.6075
# Epoch 74/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.9337 - jacard_coef: -0.1992 - loss: 0.1789
# Epoch 74: saving model to ./weights\weights.04-deeplabv3.074.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 428ms/step - accuracy: 0.9337 - jacard_coef: -0.1993 - loss: 0.1788 - val_accuracy: 0.8344 - val_jacard_coef: -0.1704 - val_loss: 0.6008
# Epoch 75/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.9363 - jacard_coef: -0.2081 - loss: 0.1683
# Epoch 75: saving model to ./weights\weights.04-deeplabv3.075.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 427ms/step - accuracy: 0.9364 - jacard_coef: -0.2081 - loss: 0.1683 - val_accuracy: 0.8688 - val_jacard_coef: -0.1940 - val_loss: 0.4506
# Epoch 76/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.9518 - jacard_coef: -0.2162 - loss: 0.1256
# Epoch 76: saving model to ./weights\weights.04-deeplabv3.076.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 429ms/step - accuracy: 0.9517 - jacard_coef: -0.2162 - loss: 0.1256 - val_accuracy: 0.8692 - val_jacard_coef: -0.1858 - val_loss: 0.4605
# Epoch 77/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.9508 - jacard_coef: -0.2132 - loss: 0.1275
# Epoch 77: saving model to ./weights\weights.04-deeplabv3.077.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 429ms/step - accuracy: 0.9508 - jacard_coef: -0.2132 - loss: 0.1275 - val_accuracy: 0.8540 - val_jacard_coef: -0.1741 - val_loss: 0.4745
# Epoch 78/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9459 - jacard_coef: -0.2083 - loss: 0.1416
# Epoch 78: saving model to ./weights\weights.04-deeplabv3.078.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 431ms/step - accuracy: 0.9459 - jacard_coef: -0.2083 - loss: 0.1416 - val_accuracy: 0.8624 - val_jacard_coef: -0.1887 - val_loss: 0.4898
# Epoch 79/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9507 - jacard_coef: -0.2099 - loss: 0.1284
# Epoch 79: saving model to ./weights\weights.04-deeplabv3.079.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 430ms/step - accuracy: 0.9507 - jacard_coef: -0.2099 - loss: 0.1284 - val_accuracy: 0.8691 - val_jacard_coef: -0.1919 - val_loss: 0.4632
# Epoch 80/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.9487 - jacard_coef: -0.2127 - loss: 0.1330
# Epoch 80: saving model to ./weights\weights.04-deeplabv3.080.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 429ms/step - accuracy: 0.9487 - jacard_coef: -0.2127 - loss: 0.1330 - val_accuracy: 0.8708 - val_jacard_coef: -0.1941 - val_loss: 0.4638
# Epoch 81/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9526 - jacard_coef: -0.2128 - loss: 0.1215
# Epoch 81: saving model to ./weights\weights.04-deeplabv3.081.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 432ms/step - accuracy: 0.9526 - jacard_coef: -0.2128 - loss: 0.1214 - val_accuracy: 0.8754 - val_jacard_coef: -0.1865 - val_loss: 0.5033
# Epoch 82/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9537 - jacard_coef: -0.2095 - loss: 0.1184
# Epoch 82: saving model to ./weights\weights.04-deeplabv3.082.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 432ms/step - accuracy: 0.9537 - jacard_coef: -0.2095 - loss: 0.1184 - val_accuracy: 0.8672 - val_jacard_coef: -0.1917 - val_loss: 0.4909
# Epoch 83/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9523 - jacard_coef: -0.2091 - loss: 0.1224
# Epoch 83: saving model to ./weights\weights.04-deeplabv3.083.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 432ms/step - accuracy: 0.9523 - jacard_coef: -0.2091 - loss: 0.1224 - val_accuracy: 0.8646 - val_jacard_coef: -0.1886 - val_loss: 0.4980
# Epoch 84/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.9523 - jacard_coef: -0.2094 - loss: 0.1241
# Epoch 84: saving model to ./weights\weights.04-deeplabv3.084.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 433ms/step - accuracy: 0.9523 - jacard_coef: -0.2094 - loss: 0.1241 - val_accuracy: 0.8649 - val_jacard_coef: -0.1919 - val_loss: 0.5292
# Epoch 85/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9560 - jacard_coef: -0.2117 - loss: 0.1140
# Epoch 85: saving model to ./weights\weights.04-deeplabv3.085.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 430ms/step - accuracy: 0.9559 - jacard_coef: -0.2116 - loss: 0.1140 - val_accuracy: 0.8664 - val_jacard_coef: -0.1815 - val_loss: 0.4869
# Epoch 86/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9494 - jacard_coef: -0.2059 - loss: 0.1321
# Epoch 86: saving model to ./weights\weights.04-deeplabv3.086.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 431ms/step - accuracy: 0.9494 - jacard_coef: -0.2059 - loss: 0.1321 - val_accuracy: 0.8581 - val_jacard_coef: -0.1851 - val_loss: 0.5406
# Epoch 87/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9507 - jacard_coef: -0.2018 - loss: 0.1261
# Epoch 87: saving model to ./weights\weights.04-deeplabv3.087.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 430ms/step - accuracy: 0.9507 - jacard_coef: -0.2018 - loss: 0.1260 - val_accuracy: 0.8708 - val_jacard_coef: -0.1827 - val_loss: 0.4888
# Epoch 88/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9560 - jacard_coef: -0.2061 - loss: 0.1134
# Epoch 88: saving model to ./weights\weights.04-deeplabv3.088.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 431ms/step - accuracy: 0.9560 - jacard_coef: -0.2061 - loss: 0.1134 - val_accuracy: 0.8706 - val_jacard_coef: -0.1814 - val_loss: 0.4840
# Epoch 89/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9560 - jacard_coef: -0.2057 - loss: 0.1126
# Epoch 89: saving model to ./weights\weights.04-deeplabv3.089.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 430ms/step - accuracy: 0.9560 - jacard_coef: -0.2057 - loss: 0.1126 - val_accuracy: 0.8688 - val_jacard_coef: -0.1867 - val_loss: 0.5154
# Epoch 90/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9558 - jacard_coef: -0.2018 - loss: 0.1132
# Epoch 90: saving model to ./weights\weights.04-deeplabv3.090.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 430ms/step - accuracy: 0.9558 - jacard_coef: -0.2018 - loss: 0.1132 - val_accuracy: 0.8709 - val_jacard_coef: -0.1874 - val_loss: 0.4874
# Epoch 91/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9569 - jacard_coef: -0.2009 - loss: 0.1109
# Epoch 91: saving model to ./weights\weights.04-deeplabv3.091.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 431ms/step - accuracy: 0.9569 - jacard_coef: -0.2009 - loss: 0.1109 - val_accuracy: 0.8700 - val_jacard_coef: -0.1869 - val_loss: 0.5223
# Epoch 92/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9548 - jacard_coef: -0.1972 - loss: 0.1168
# Epoch 92: saving model to ./weights\weights.04-deeplabv3.092.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 432ms/step - accuracy: 0.9548 - jacard_coef: -0.1972 - loss: 0.1168 - val_accuracy: 0.8680 - val_jacard_coef: -0.1595 - val_loss: 0.5190
# Epoch 93/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9537 - jacard_coef: -0.1947 - loss: 0.1196
# Epoch 93: saving model to ./weights\weights.04-deeplabv3.093.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 430ms/step - accuracy: 0.9537 - jacard_coef: -0.1947 - loss: 0.1196 - val_accuracy: 0.8627 - val_jacard_coef: -0.1656 - val_loss: 0.5028
# Epoch 94/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9564 - jacard_coef: -0.1940 - loss: 0.1109
# Epoch 94: saving model to ./weights\weights.04-deeplabv3.094.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 430ms/step - accuracy: 0.9564 - jacard_coef: -0.1940 - loss: 0.1109 - val_accuracy: 0.8655 - val_jacard_coef: -0.1741 - val_loss: 0.5275
# Epoch 95/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.9596 - jacard_coef: -0.1963 - loss: 0.1034
# Epoch 95: saving model to ./weights\weights.04-deeplabv3.095.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 429ms/step - accuracy: 0.9596 - jacard_coef: -0.1963 - loss: 0.1034 - val_accuracy: 0.8279 - val_jacard_coef: -0.1666 - val_loss: 0.7364
# Epoch 96/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9597 - jacard_coef: -0.1956 - loss: 0.1031
# Epoch 96: saving model to ./weights\weights.04-deeplabv3.096.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 112s 431ms/step - accuracy: 0.9597 - jacard_coef: -0.1956 - loss: 0.1033 - val_accuracy: 0.7601 - val_jacard_coef: -0.1063 - val_loss: 1.2981
# Epoch 97/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9261 - jacard_coef: -0.1751 - loss: 0.1991
# Epoch 97: saving model to ./weights\weights.04-deeplabv3.097.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 431ms/step - accuracy: 0.9262 - jacard_coef: -0.1752 - loss: 0.1989 - val_accuracy: 0.8659 - val_jacard_coef: -0.1783 - val_loss: 0.4819
# Epoch 98/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9575 - jacard_coef: -0.1906 - loss: 0.1093
# Epoch 98: saving model to ./weights\weights.04-deeplabv3.098.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 431ms/step - accuracy: 0.9575 - jacard_coef: -0.1906 - loss: 0.1093 - val_accuracy: 0.8730 - val_jacard_coef: -0.1704 - val_loss: 0.4990
# Epoch 99/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9610 - jacard_coef: -0.1925 - loss: 0.0989
# Epoch 99: saving model to ./weights\weights.04-deeplabv3.099.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 113s 431ms/step - accuracy: 0.9610 - jacard_coef: -0.1925 - loss: 0.0989 - val_accuracy: 0.7588 - val_jacard_coef: -0.1598 - val_loss: 0.8170
# Epoch 100/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.9593 - jacard_coef: -0.1904 - loss: 0.1040
# Epoch 100: saving model to ./weights\weights.04-deeplabv3.100.weights.h5
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 441ms/step - accuracy: 0.9593 - jacard_coef: -0.1904 - loss: 0.1040 - val_accuracy: 0.8638 - val_jacard_coef: -0.1628 - val_loss: 0.5218
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model

# model = load_model("./models/standard_unet_100epochs.hdf5",
#                    custom_objects={'dice_loss_plus_2focal_loss': total_loss(),
#                                    'jacard_coef':jacard_coef()})

model = load_model("./models/unet_with_deeplabv3+_backbone_100epochs.hdf5", compile=False)

# IOU
y_pred=model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)
y_test_argmax=np.argmax(y_test, axis=3)


# Using built in keras function for IoU
from tensorflow.keras.metrics import MeanIoU
n_classes = 6
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(y_test_argmax, y_pred_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 672ms/step
# Mean IoU = 0.6055543

# %%
# Predict on a few images

import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test_argmax[test_img_number]
# test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on Test Image')
plt.imshow(predicted_img)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['jacard_coef']
val_acc = history.history['val_jacard_coef']

plt.plot(epochs, acc, 'y', label='Training IoU')
plt.plot(epochs, val_acc, 'r', label='Validation IoU')
plt.title('Training and validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()
